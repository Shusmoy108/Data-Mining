# %% [markdown]
# # Name: Shusmoy Chowdhury

# %% [markdown]
# # Getting to know the data:

# %% [markdown]
# # 1.	Load the data in a DataFrame (DF) named tips.

# %%
# Name: Shusmoy Chowdhury
import pandas as pd
#import numpy as np
import matplotlib.pyplot as plt
tips_data=pd.read_csv("tips.csv")

# %% [markdown]
# # 2.	Find the names of the columns.

# %%
tips_data.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# # 3.	[3 points] Rename the columns “time” as “meal” and “size” as “party size

# %%
#renamed_tips_data=tips_data.rename({'time':'meal' , 'size': 'party size' },axis=1)
tips_data.rename({'time':'meal' , 'size': 'party size' },axis=1, inplace=True)
tips_data.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'meal', 'party size'], dtype='object')

# %% [markdown]
# # 4.	Use the head function to view parts of the data.

# %%
tips_data.head()
# Out:
#    total_bill   tip     sex smoker  day    meal  party size
# 0       16.99  1.01  Female     No  Sun  Dinner           2
# 1       10.34  1.66    Male     No  Sun  Dinner           3
# 2       21.01  3.50    Male     No  Sun  Dinner           3
# 3       23.68  3.31    Male     No  Sun  Dinner           2
# 4       24.59  3.61  Female     No  Sun  Dinner           4

# %% [markdown]
# # 5.	Retrieve the information in the second and third rows using two different methods (you can use .loc, .iloc, or the slicing notation, :).

# %%
tips_data.iloc[1:3]
# Out:
#    total_bill   tip   sex smoker  day    meal  party size
# 1       10.34  1.66  Male     No  Sun  Dinner           3
# 2       21.01  3.50  Male     No  Sun  Dinner           3

# %% [markdown]
# # 6.	Retrieve the information in the first and second columns (i.e., under total_bill and tip). Use the head function to display the first three rows under these two columns

# %%
tips_data[1:3]
# Out:
#    total_bill   tip   sex smoker  day    meal  party size
# 1       10.34  1.66  Male     No  Sun  Dinner           3
# 2       21.01  3.50  Male     No  Sun  Dinner           3

# %% [markdown]
# # 6.	Retrieve the information in the first and second columns (i.e., under total_bill and tip). Use the head function to display the first three rows under these two columns

# %%
tips_data[['total_bill','tip']].head(3)
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50

# %% [markdown]
# # 7.	Get the information stored in the cell at the intersection of the second row and third column. I.e., what is the sex of the customer (that paid for the meal) that is stored in the second row of the DF?

# %%
tips_data.iloc[1,[2]]
# Out:
# sex    Male
# Name: 1, dtype: object

# %% [markdown]
# # 8.	Find the number of observations in the dataset

# %%
len(tips_data.index)
# Out:
# 244

# %% [markdown]
# # 9.	Use the describe function to get basic statistics about the numerical attributes

# %%
tips_data.describe()
# Out:
#        total_bill         tip  party size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# # 10.	Use the describe function to get basic statistics about all attributes. It is okay to have the value NaN shown in some places

# %%
tips_data.describe(include="all")
# Out:
#         total_bill         tip   sex smoker  day    meal  party size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %% [markdown]
# # How much tip do customers usually give on average?

# %% [markdown]
# # 11.	Find the average tip amount.

# %%
tip=tips_data['tip']
tip.mean()
# Out:
# 2.9982786885245902

# %% [markdown]
# # 12.	Get basic statistics about the tip column using the describe function. This helps give an idea about the min, max, median values of tip in addition to other basic statistics.

# %%
tip.describe()  #12
# Out:
# count    244.000000
# mean       2.998279
# std        1.383638
# min        1.000000
# 25%        2.000000
# 50%        2.900000
# 75%        3.562500
# max       10.000000
# Name: tip, dtype: float64

# %% [markdown]
# # 13.	Draw a boxplot of the tip column. This gives a visual representation of the tips data and shows outliers.

# %%
plt.title("Boxplots of Tips")
plt.ylabel("Tip")
plt.boxplot(tip)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1abc893cee0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1abc8ffc580>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1abc893cc10>],
#  'medians': [<matplotlib.lines.Line2D at 0x1abc8ffca60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1abc8ffcd30>],
#  'means': []}

# %% [markdown]
# # 14.	[3 points] From the boxplot, it looks that the outliers are for tips >= 6. Retrieve the rows where the tip amount is >= 6.

# %%
tips_data.loc[tips_data['tip'] >=6]
# Out:
#      total_bill    tip     sex smoker   day    meal  party size
# 23        39.42   7.58    Male     No   Sat  Dinner           4
# 47        32.40   6.00    Male     No   Sun  Dinner           4
# 59        48.27   6.73    Male     No   Sat  Dinner           4
# 141       34.30   6.70    Male     No  Thur   Lunch           6
# 170       50.81  10.00    Male    Yes   Sat  Dinner           3
# 183       23.17   6.50    Male    Yes   Sun  Dinner           4
# 212       48.33   9.00    Male     No   Sat  Dinner           4
# 214       28.17   6.50  Female    Yes   Sat  Dinner           3

# %% [markdown]
# # Do male customers usually give more tip than female customers?

# %% [markdown]
# # 16.	[3 points] Use the groupby function to find the average tip amount per sex. i.e., find the average tip by male customers and the average tip by female customers. It is okay if your command gives the averages for all numeric attributes.

# %%
sex_grouped_tip=tips_data['tip'].groupby(renamed_tips_data['sex'])#16
sex_grouped_tip.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 sex_grouped_tip=tips_data['tip'].groupby(renamed_tips_data['sex'])#16
#       2 sex_grouped_tip.mean()
#
# NameError: name 'renamed_tips_data' is not defined

# %% [markdown]
# # 17.	Create a DF named males that contains the male samples in the tips DF. Then, call males.sample(10) to draw a random sample of 10 male observations

# %%
males= tips_data.loc[tips_data['sex'] == "Male"]
males.sample(10)

# %% [markdown]
# # 18.	Create a DF named females that contains the female samples in the tips DF. Then, call females.sample(frac=0.1, replace = True) to generate and display a random sample with replacement that consists of 10% of the size of the females DF.

# %%
females= tips_data.loc[tips_data['sex'] == "Female"]
females.sample(frac=0.1, replace = True)
# Out:
#      total_bill   tip     sex smoker   day    meal  party size
# 155       29.85  5.14  Female     No   Sun  Dinner           5
# 134       18.26  3.25  Female     No  Thur   Lunch           2
# 119       24.08  2.92  Female     No  Thur   Lunch           4
# 135        8.51  1.25  Female     No  Thur   Lunch           2
# 51        10.29  2.60  Female     No   Sun  Dinner           2
# 101       15.38  3.00  Female    Yes   Fri  Dinner           2
# 73        25.28  5.00  Female    Yes   Sat  Dinner           2
# 111        7.25  1.00  Female     No   Sat  Dinner           1
# 71        17.07  3.00  Female     No   Sat  Dinner           3

# %% [markdown]
# # 19.	Write code to find out the number of male customers and the number of female customers.

# %%
tips_data['tip'].groupby(tips_data['sex']).count()
# Out:
# sex
# Female     87
# Male      157
# Name: tip, dtype: int64

# %% [markdown]
# # 20.	[5 points] Create a bar chart comparing the number of males and number of females in the dataset. Give labels to the x-axis, y-axis, and a title to the plot. Sample display is as follows

# %%
x=["Male", "Female"]
y=[]
y.append(len(males.index))
y.append(len(females.index))
plt.title("Comparing Number of Customers Based on Gender")
plt.xlabel("Gender")
plt.ylabel("Number of Customer")
plt.bar(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 3>()
#       1 x=["Male", "Female"]
#       2 y=[]
# ----> 3 y.append(len(males.index))
#       4 y.append(len(females.index))
#       5 plt.title("Comparing Number of Customers Based on Gender")
#
# NameError: name 'males' is not defined

# %% [markdown]
# # 21.	[5 points] Draw a scatter plot of the tips given by male customers and a scatter plot of the tips given by female customers. Notice, for easier comparison, you need to show the two scatter plots in the same subplot area. Make sure to label the data and show a legend. Sample display is as follows:

# %%
plt.subplot(111)
plt.plot([x for x in range(len(males.index))], males['tip'],"P",color="r",label="male")
plt.plot([x for x in range(len(females.index))], females['tip'],"*",color="b", label="female")
plt.legend()
#males.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 2>()
#       1 plt.subplot(111)
# ----> 2 plt.plot([x for x in range(len(males.index))], males['tip'],"P",color="r",label="male")
#       3 plt.plot([x for x in range(len(females.index))], females['tip'],"*",color="b", label="female")
#       4 plt.legend()
#
# NameError: name 'males' is not defined

# %% [markdown]
# # [5 points] Draw two box plots to show tips per sex. One box plot to show the tips by females while the other to shows tips by males. Show both plots in the same area (i.e., do not create separate subplot areas for each boxplot because that is visually easier to compare.) Label the diagram as shown in the following sample display

# %%
plt.boxplot([females['tip'],males['tip']], labels=["Female","Male"])
plt.title("Boxplots of Tips by Gender")
plt.xlabel("Gender")
plt.ylabel("Tip")
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# # What day(s) of the week is the restaurant the busiest?

# %% [markdown]
# # 23.	Apply the describe function on the “day” column of the tips DF and observe the result.

# %%
tips_data['day'].describe() #23
# Out:
# count     244
# unique      4
# top       Sat
# freq       87
# Name: day, dtype: object

# %% [markdown]
# # 24.	[3 points] Use the groupby function to form groups based on the days of the week and find the number of customers that were served every data?

# %%
day_grouped_data=tips_data['party size'].groupby(tips_data['day'])#24
day_grouped_data.count()
# Out:
# day
# Fri     19
# Sat     87
# Sun     76
# Thur    62
# Name: party size, dtype: int64

# %% [markdown]
# # 25.	[5 points] Draw a line plot that shows number of customers served every day. Notice: you do not need to worry about the individual customers as shown under the size attribute. We are treating each observation, regardless of party size, as one customer.

# %%
plt.plot([0.0,1.0,2.0,3.0],[day_grouped_data.count()['Thur'],day_grouped_data.count()['Fri'],day_grouped_data.count()['Sat'],day_grouped_data.count()['Sun']])
plt.xticks([0.0,1.0,2.0,3.0],["Thursday",'Friday',"Saturday","Sunday"])
plt.grid(True)
plt.title("Number of Customers Per Day")
plt.xlabel("Day")
plt.ylabel("Number of Customer")
# Out:
# Text(0, 0.5, 'Number of Customer')

# %% [markdown]
# # 26.	[3 points] Use the groupby function to find the average tip per day? Store these averages in variables. These variables will be used next to display the averages in plots.

# %%
day_grouped_data=tips_data['tip'].groupby(tips_data['day'])
day_grouped_data.mean()#26
# Out:
# day
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Thur    2.771452
# Name: tip, dtype: float64

# %% [markdown]
# # [6 points] Draw a figure with 2 by 2 subplots. Each subplot shows a line plot of the tips given on a certain day. Show the average tip in each subplot. For example, these are shown as red asterisks in the diagram below. Give titles to the different subplots as well as a title to the whole figure. The line plt.figure(figsize=(8, 8)) can be used to specify figure dimensions in inches. Sample output is as follows:

# %%
thur= tips_data.loc[tips_data['day'] == "Thur"]
fri= tips_data.loc[tips_data['day'] == "Fri"]
sat= tips_data.loc[tips_data['day'] == "Sat"]
sun= tips_data.loc[tips_data['day'] == "Sun"]
plt.figure(figsize=(8, 8)) 
plt.suptitle("Tips of Different Days", fontsize=15, color='red')
plt.subplot(221)
plt.plot([0], [thur['tip'].mean()],"*",color="r",)
plt.plot(thur.index,thur['tip'])
plt.title("Thursday")
plt.subplot(222)
plt.plot([0], [fri['tip'].mean()],"*",color="r",)
plt.plot(fri.index,fri['tip'])
plt.title("Friday")
plt.subplot(223)
plt.plot([0], [sat['tip'].mean()],"*",color="r",)
plt.plot(sat.index,sat['tip'])
plt.title("Satday")
plt.subplot(224)
plt.plot([0], [sun['tip'].mean()],"*",color="r",)
plt.plot(sun.index,sun['tip'])
plt.title("Sunday")
plt.tight_layout()

# %% [markdown]
# # [5 points] Draw a pie chart to compare the total tip amounts collected on the different days. Make sure the pie chart shows as a perfect square. Show percentages (including the percent sign, %,) and labels as shown in the following figure

# %%
plt.pie([fri["tip"].sum(),sat["tip"].sum(),sun["tip"].sum(),thur["tip"].sum()],labels=["Fri","Sat","Sun",'Thur'], autopct="%0.2f%%")
plt.axis('equal')
# Out:
# (-1.1107643640172367,
#  1.1005125887627256,
#  -1.113064506985197,
#  1.1018417142203594)

# %%
salary_data=pd.read_csv("ds_salaries.csv")
salary_data.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
#Do excecutive level employees usually get more salary than other employees? 
exp=salary_data['salary_in_usd'].groupby(salary_data['experience_level'])
exp.mean()
# Out:
# experience_level
# EN     61643.318182
# EX    199392.038462
# MI     87996.056338
# SE    138617.292857
# Name: salary_in_usd, dtype: float64

# %%
mi= salary_data.loc[salary_data['experience_level'] == "MI"]
mi.sample(10)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 538         538       2022               MI              FT
# 61           61       2020               MI              FT
# 282         282       2021               MI              PT
# 184         184       2021               MI              FL
# 169         169       2021               MI              FT
# 182         182       2021               MI              FT
# 23           23       2020               MI              FT
# 522         522       2022               MI              FT
# 245         245       2021               MI              FT
# 242         242       2021               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 538              Data Scientist  141300             USD         141300
# 61                Data Engineer  130800             USD         130800
# 282               Data Engineer   59000             EUR          69741
# ...

# %%
en= salary_data.loc[salary_data['experience_level'] == "EN"]
en.sample(frac=0.1, replace = True)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 68           68       2020               EN              FT
# 304         304       2022               EN              FT
# 153         153       2021               EN              FT
# 510         510       2022               EN              FT
# 163         163       2021               EN              FT
# 96           96       2021               EN              PT
# 109         109       2021               EN              FT
# 123         123       2021               EN              FT
# 489         489       2022               EN              CT
#
#                               job_title   salary salary_currency  \
# 68                       Data Scientist   105000             USD
# 304                       Data Engineer    40000             GBP
# 153                      Data Scientist    13400             USD
# 510   Computer Vision Software Engineer   150000             USD
# ...

# %%
ex= salary_data.loc[salary_data['experience_level'] == "EX"]
ex.sample(frac=0.1, replace = True)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 73           73       2021               EX              FT
# 384         384       2022               EX              FT
# 344         344       2022               EX              FT
#
#                     job_title   salary salary_currency  salary_in_usd  \
# 73            BI Data Analyst   150000             USD         150000
# 384  Head of Machine Learning  6000000             INR          79039
# 344        Analytics Engineer   175000             USD         175000
#
#     employee_residence  remote_ratio company_location company_size
# 73                  IN           100               US            L
# 384                 IN            50               IN            L
# 344                 US           100               US            M

# %%
se= salary_data.loc[salary_data['experience_level'] == "SE"]
se.sample(frac=0.1, replace = True)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 392         392       2022               SE              FT
# 332         332       2022               SE              FT
# 592         592       2022               SE              FT
# 357         357       2022               SE              FT
# 582         582       2022               SE              FT
# 232         232       2021               SE              FT
# 423         423       2022               SE              FT
# 145         145       2021               SE              FT
# 393         393       2022               SE              FT
# 149         149       2021               SE              FT
# 206         206       2021               SE              FT
# 265         265       2021               SE              FT
# 341         341       2022               SE              FT
# 345         345       2022               SE              FT
# 540         540       2022               SE              FT
# ...

# %%
salary_data['salary_in_usd'].groupby(salary_data['experience_level']).count()
# Out:
# experience_level
# EN     88
# EX     26
# MI    213
# SE    280
# Name: salary_in_usd, dtype: int64

# %%
x=["Entry-level", "Mid-level","Senior-level", "Executive-level"]
y=[]
y.append(len(en.index))
y.append(len(mi.index))
y.append(len(se.index))
y.append(len(ex.index))
plt.title("Comparing Number of Employees Based on Experience Level")
plt.xlabel("Experience Level")
plt.ylabel("Number of Employees")
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.subplot(111)
plt.plot([x for x in range(len(en.index))], en['salary_in_usd'],"P",color="r",label="Entry-level")
plt.plot([x for x in range(len(mi.index))], mi['salary_in_usd'],"*",color="b", label="Mid-level")
plt.plot([x for x in range(len(se.index))], se['salary_in_usd'],"s",color="g",label="Senior-level")
plt.plot([x for x in range(len(ex.index))], ex['salary_in_usd'],"H",color="brown", label="Executive-level")
plt.legend()

# %%
plt.boxplot([en['salary_in_usd'],mi['salary_in_usd'],se['salary_in_usd'],ex['salary_in_usd']], labels=["Entry-level", "Mid-level","Senior-level", "Executive-level"])
plt.title("Boxplots of Salaries by Experience Level")
plt.xlabel("Salary")
plt.ylabel("Experience Level")
# Out:
# Text(0, 0.5, 'Experience Level')

# %%
#Do employees tends to get more salary based on their experience level?
exp_grouped_data=salary_data['salary_in_usd'].groupby(salary_data['experience_level'])
exp_grouped_data.mean()#26
#salary_data['salary_in_usd'].groupby(salary_data['experience_level']).count()
# Out:
# experience_level
# EN     61643.318182
# EX    199392.038462
# MI     87996.056338
# SE    138617.292857
# Name: salary_in_usd, dtype: float64

# %%
en= salary_data.loc[salary_data['experience_level'] == "EN"]
mi= salary_data.loc[salary_data['experience_level'] == "MI"]
ex= salary_data.loc[salary_data['experience_level'] == "EX"]
se= salary_data.loc[salary_data['experience_level'] == "SE"]
plt.figure(figsize=(8, 8)) 
plt.suptitle("Salaries of Different Employees", fontsize=15, color='red')
plt.subplot(221)
plt.plot([0], [en['salary_in_usd'].mean()],"*",color="r",)
plt.plot(en.index,en['salary_in_usd'])
plt.title("Entry Level")
plt.subplot(222)
plt.plot([0], [mi['salary_in_usd'].mean()],"*",color="r",)
plt.plot(mi.index,mi['salary_in_usd'])
plt.title("Mid-level")
plt.subplot(223)
plt.plot([0], [se['salary_in_usd'].mean()],"*",color="r",)
plt.plot(se.index,se['salary_in_usd'])
plt.title("Senior-level")
plt.subplot(224)
plt.plot([0], [ex['salary_in_usd'].mean()],"*",color="r",)
plt.plot(ex.index,ex['salary_in_usd'])
plt.title("Executive-level")
plt.tight_layout()

# %%
#plt.pie([en["salary_in_usd"].mean(),mi["salary_in_usd"].mean(),se["salary_in_usd"].mean(),ex["salary_in_usd"].mean()],labels=["Entry-level", "Mid-level","Senior-level", "Executive-level"], autopct="%0.2f%%")
plt.pie([en["salary_in_usd"].sum(),mi["salary_in_usd"].sum(),se["salary_in_usd"].sum(),ex["salary_in_usd"].sum()],labels=["Entry-level", "Mid-level","Senior-level", "Executive-level"], autopct="%0.2f%%")
plt.axis('equal')
# Out:
# (-1.1028633939438122,
#  1.1001363520925624,
#  -1.1107919889656575,
#  1.1092725187004435)

# %%
#Do contractual employee work more remotely than the part timer, full timer or freelancers?
et=salary_data['remote_ratio'].groupby(salary_data['employment_type'])
et.mean()
# Out:
# employment_type
# CT    100.000000
# FL     62.500000
# FT     70.748299
# PT     70.000000
# Name: remote_ratio, dtype: float64

# %%
cl= salary_data.loc[salary_data['employment_type'] == "CT"]
cl.sample(5)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 489         489       2022               EN              CT
# 78           78       2021               MI              CT
# 283         283       2021               SE              CT
# 225         225       2021               EX              CT
# 28           28       2020               EN              CT
#
#                               job_title  salary salary_currency  \
# 489  Applied Machine Learning Scientist   29000             EUR
# 78                          ML Engineer  270000             USD
# 283                Staff Data Scientist  105000             USD
# 225            Principal Data Scientist  416000             USD
# 28                Business Data Analyst  100000             USD
#
#      salary_in_usd employee_residence  remote_ratio company_location  \
# 489          31875                 TN           100               CZ
# 78          270000                 US           100               US
# ...

# %%
ft= salary_data.loc[salary_data['employment_type'] == "FT"]
ft.sample(frac=0.1, replace = True)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 129         129       2021               SE              FT
# 15           15       2020               MI              FT
# 303         303       2022               SE              FT
# 562         562       2022               SE              FT
# 55           55       2020               SE              FT
# 307         307       2022               MI              FT
# 336         336       2022               MI              FT
# 186         186       2021               SE              FT
# 165         165       2021               SE              FT
# 454         454       2022               EN              FT
# 586         586       2022               MI              FT
# 343         343       2022               EX              FT
# 273         273       2021               EN              FT
# 173         173       2021               SE              FT
# 0             0       2020               MI              FT
# ...

# %%
fl =salary_data.loc[salary_data['employment_type'] == "FL"]
#fl.count()
fl.sample(frac=0.1, replace = True)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, work_year, experience_level, employment_type, job_title, salary, salary_currency, salary_in_usd, employee_residence, remote_ratio, company_location, company_size]
# Index: []

# %%
pt= salary_data.loc[salary_data['employment_type'] == "PT"]
pt.sample(frac=0.1, replace = True)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 216         216       2021               EN              PT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 216  Computer Vision Engineer  180000             DKK          28609
#
#     employee_residence  remote_ratio company_location company_size
# 216                 DK            50               DK            S

# %%
salary_data['remote_ratio'].groupby(salary_data['employment_type']).count()
# Out:
# employment_type
# CT      5
# FL      4
# FT    588
# PT     10
# Name: remote_ratio, dtype: int64

# %%
x=["Part-time", "Full-time","Contract", "Freelance"]
y=[]
y.append(len(pt.index))
y.append(len(ft.index))
y.append(len(cl.index))
y.append(len(fl.index))
plt.title("Comparing Number of Employees Based on Employment Type")
plt.xlabel("Employment Type")
plt.ylabel("Number of Employees")
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.subplot(111)
plt.plot([x for x in range(len(pt.index))], pt['remote_ratio'],"P",color="r",label="Part-Time")
plt.plot([x for x in range(len(ft.index))], ft['remote_ratio'],"*",color="b", label="Full-Time")
plt.plot([x for x in range(len(cl.index))], cl['remote_ratio'],"s",color="g",label="Contractual")
plt.plot([x for x in range(len(fl.index))], fl['remote_ratio'],"H",color="brown", label="Freelancer")
plt.legend()

# %%
plt.boxplot([pt['remote_ratio'],fl['remote_ratio'],cl['remote_ratio'],fl['remote_ratio']], labels=["Part-time", "Full-time","Contract", "Freelance"])
plt.title("Boxplots of Remote Ratio by Employee Type")
plt.xlabel("Remote Ratio")
plt.ylabel("Employee Type")
# Out:
# Text(0, 0.5, 'Employee Type')

# %%
# Is the salary of the employeess increasing year by year?
year_grouped_data=salary_data['salary_in_usd'].groupby(salary_data['work_year'])
year_grouped_data.mean()
#salary_data['salary_in_usd'].groupby(salary_data['work_year']).count()
# Out:
# work_year
# 2020     95813.000000
# 2021     99853.792627
# 2022    124522.006289
# Name: salary_in_usd, dtype: float64

# %%
y1= salary_data.loc[salary_data['work_year'] == 2020]
y1.sample(frac=0.1, replace = True)
# Out:
#     Unnamed: 0  work_year experience_level employment_type  \
# 63          63       2020               SE              FT
# 63          63       2020               SE              FT
# 61          61       2020               MI              FT
# 50          50       2020               EN              FT
# 48          48       2020               MI              FT
# 39          39       2020               EN              FT
# 20          20       2020               MI              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 63             Data Scientist  412000             USD         412000
# 63             Data Scientist  412000             USD         412000
# 61              Data Engineer  130800             USD         130800
# 50               Data Analyst  450000             INR           6072
# 48             Data Scientist  105000             USD         105000
# 39  Machine Learning Engineer  138000             USD         138000
# ...

# %%
y2= salary_data.loc[salary_data['work_year'] == 2021]
y2.sample(frac=0.1, replace = True)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 135         135       2021               MI              FT
# 105         105       2021               MI              FT
# 184         184       2021               MI              FL
# 146         146       2021               MI              FT
# 204         204       2021               MI              FT
# 179         179       2021               MI              FT
# 115         115       2021               EN              FT
# 182         182       2021               MI              FT
# 269         269       2021               EN              FT
# 138         138       2021               SE              FT
# 234         234       2021               MI              FT
# 229         229       2021               SE              FT
# 221         221       2021               MI              FT
# 254         254       2021               MI              FT
# 240         240       2021               SE              FT
# ...

# %%
y3= salary_data.loc[salary_data['work_year'] == 2022]
y3.sample(10)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 552         552       2022               SE              FT
# 463         463       2022               EN              FT
# 291         291       2022               SE              FT
# 585         585       2022               SE              FT
# 348         348       2022               SE              FT
# 381         381       2022               SE              FT
# 329         329       2022               MI              FT
# 330         330       2022               SE              FT
# 368         368       2022               EX              FT
# 445         445       2022               MI              FT
#
#               job_title   salary salary_currency  salary_in_usd  \
# 552      Data Scientist   176000             USD         176000
# 463      Data Scientist  1400000             INR          18442
# 291        Data Analyst   120600             USD         120600
# ...

# %%
year_grouped_data=salary_data['salary_in_usd'].groupby(salary_data['work_year'])
year_grouped_data.count()
# Out:
# work_year
# 2020     72
# 2021    217
# 2022    318
# Name: salary_in_usd, dtype: int64

# %%
x=["2020", "2021","2022"]
y=[]
y.append(len(y1.index))
y.append(len(y2.index))
y.append(len(y3.index))
plt.title("Comparing Number of Employees Based on Year")
plt.xlabel("Year")
plt.ylabel("Number of Employees")
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.subplot(111)
plt.plot([x for x in range(len(y1.index))], y1['salary_in_usd'],"P",color="r",label="2020")
plt.plot([x for x in range(len(y2.index))], y2['salary_in_usd'],"*",color="b", label="2021")
plt.plot([x for x in range(len(y3.index))], y3['salary_in_usd'],"s",color="g",label="2022")
plt.legend()

# %%
plt.boxplot([y1['salary_in_usd'],y2['salary_in_usd'],y3['salary_in_usd']], labels=["2020", "2021","2022"])
plt.title("Boxplots of Salary by Year")
plt.xlabel("Salary")
plt.ylabel("Year")
# Out:
# Text(0, 0.5, 'Year')
