# %%
# Name: Shusmoy Chowdhury
import pandas as pd
#import numpy as np
import matplotlib.pyplot as plt
tips_data=pd.read_csv("tips.csv")

# %%
tips_data.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
#renamed_tips_data=tips_data.rename({'time':'meal' , 'size': 'party size' },axis=1)
tips_data.rename({'time':'meal' , 'size': 'party size' },axis=1, inplace=True)
tips_data.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'meal', 'party size'], dtype='object')

# %%
tips_data.head()
# Out:
#    total_bill   tip     sex smoker  day    meal  party size
# 0       16.99  1.01  Female     No  Sun  Dinner           2
# 1       10.34  1.66    Male     No  Sun  Dinner           3
# 2       21.01  3.50    Male     No  Sun  Dinner           3
# 3       23.68  3.31    Male     No  Sun  Dinner           2
# 4       24.59  3.61  Female     No  Sun  Dinner           4

# %%
tips_data.iloc[1:3]
# Out:
#    total_bill   tip   sex smoker  day    meal  party size
# 1       10.34  1.66  Male     No  Sun  Dinner           3
# 2       21.01  3.50  Male     No  Sun  Dinner           3

# %%
tips_data[1:3]
# Out:
#    total_bill   tip   sex smoker  day    meal  party size
# 1       10.34  1.66  Male     No  Sun  Dinner           3
# 2       21.01  3.50  Male     No  Sun  Dinner           3

# %%
tips_data[['total_bill','tip']].head(3)
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50

# %%
tips_data.iloc[1,[2]]
# Out:
# sex    Male
# Name: 1, dtype: object

# %%
len(tips_data.index)
# Out:
# 244

# %%
tips_data.describe()
# Out:
#        total_bill         tip  party size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips_data.describe(include="all")
# Out:
#         total_bill         tip   sex smoker  day    meal  party size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
tip=tips_data['tip']
tip.mean()
# Out:
# 2.9982786885245902

# %%
tip.describe()  #12
# Out:
# count    244.000000
# mean       2.998279
# std        1.383638
# min        1.000000
# 25%        2.000000
# 50%        2.900000
# 75%        3.562500
# max       10.000000
# Name: tip, dtype: float64

# %%
plt.title("Boxplots of Tips")
plt.ylabel("Tip")
plt.boxplot(tip)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1eef9da2e50>,
#   <matplotlib.lines.Line2D at 0x1eef9db2220>],
#  'caps': [<matplotlib.lines.Line2D at 0x1eef9db25b0>,
#   <matplotlib.lines.Line2D at 0x1eef9db2940>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1eef9da2ac0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1eef9db2cd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1eef9dbd0a0>],
#  'means': []}

# %%
tips_data.loc[tips_data['tip'] >=6]
# Out:
#      total_bill    tip     sex smoker   day    meal  party size
# 23        39.42   7.58    Male     No   Sat  Dinner           4
# 47        32.40   6.00    Male     No   Sun  Dinner           4
# 59        48.27   6.73    Male     No   Sat  Dinner           4
# 141       34.30   6.70    Male     No  Thur   Lunch           6
# 170       50.81  10.00    Male    Yes   Sat  Dinner           3
# 183       23.17   6.50    Male    Yes   Sun  Dinner           4
# 212       48.33   9.00    Male     No   Sat  Dinner           4
# 214       28.17   6.50  Female    Yes   Sat  Dinner           3

# %%
sex_grouped_tip=tips_data['tip'].groupby(renamed_tips_data['sex'])#16
sex_grouped_tip.mean()
# Out:
# sex
# Female    2.833448
# Male      3.089618
# Name: tip, dtype: float64

# %%
males= tips_data.loc[tips_data['sex'] == "Male"]
males.sample(10)
# Out:
#      total_bill   tip   sex smoker   day    meal  party size
# 120       11.69  2.31  Male     No  Thur   Lunch           2
# 153       24.55  2.00  Male     No   Sun  Dinner           4
# 31        18.35  2.50  Male     No   Sat  Dinner           4
# 239       29.03  5.92  Male     No   Sat  Dinner           3
# 91        22.49  3.50  Male     No   Fri  Dinner           2
# 173       31.85  3.18  Male    Yes   Sun  Dinner           2
# 179       34.63  3.55  Male    Yes   Sun  Dinner           2
# 235       10.07  1.25  Male     No   Sat  Dinner           2
# 50        12.54  2.50  Male     No   Sun  Dinner           2
# 62        11.02  1.98  Male    Yes   Sat  Dinner           2

# %%
females= tips_data.loc[tips_data['sex'] == "Female"]
females.sample(frac=0.1, replace = True)
# Out:
#      total_bill   tip     sex smoker   day    meal  party size
# 191       19.81  4.19  Female    Yes  Thur   Lunch           2
# 136       10.33  2.00  Female     No  Thur   Lunch           2
# 16        10.33  1.67  Female     No   Sun  Dinner           3
# 11        35.26  5.00  Female     No   Sun  Dinner           4
# 18        16.97  3.50  Female     No   Sun  Dinner           3
# 114       25.71  4.00  Female     No   Sun  Dinner           3
# 178        9.60  4.00  Female    Yes   Sun  Dinner           2
# 137       14.15  2.00  Female     No  Thur   Lunch           2
# 186       20.90  3.50  Female    Yes   Sun  Dinner           3

# %%
tips_data['tip'].groupby(tips_data['sex']).count()
# Out:
# sex
# Female     87
# Male      157
# Name: tip, dtype: int64

# %%
x=["Male", "Female"]
y=[]
y.append(len(males.index))
y.append(len(females.index))
plt.title("Comparing Number of Customers Based on Gender")
plt.xlabel("Gender")
plt.ylabel("Number of Customer")
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
plt.subplot(111)
plt.plot([x for x in range(len(males.index))], males['tip'],"+",color="r",label="male")
plt.plot([x for x in range(len(females.index))], females['tip'],"*",color="b", label="female")
plt.legend()
#males.index

# %%
plt.boxplot([females['tip'],males['tip']], labels=["Female","Male"])
plt.title("Boxplots of Tips by Gender")
plt.xlabel("Gender")
plt.ylabel("Tip")
# Out:
# Text(0, 0.5, 'Tip')

# %%
tips_data['day'].describe() #23
# Out:
# count     244
# unique      4
# top       Sat
# freq       87
# Name: day, dtype: object

# %%
day_grouped_data=tips_data['party size'].groupby(tips_data['day'])#24
day_grouped_data.count()
# Out:
# day
# Fri     19
# Sat     87
# Sun     76
# Thur    62
# Name: party size, dtype: int64

# %%
plt.plot([0.0,1.0,2.0,3.0],[day_grouped_data.count()['Thur'],day_grouped_data.count()['Fri'],day_grouped_data.count()['Sat'],day_grouped_data.count()['Sun']])
plt.xticks([0.0,1.0,2.0,3.0],["Thursday",'Friday',"Saturday","Sunday"])
plt.grid(True)
plt.title("Number of Customers Per Day")
plt.xlabel("Day")
plt.ylabel("Number of Customer")
# Out:
# Text(0, 0.5, 'Number of Customer')

# %%
day_grouped_data=tips_data['tip'].groupby(tips_data['day'])
day_grouped_data.mean()#26
# Out:
# day
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Thur    2.771452
# Name: tip, dtype: float64

# %%
thur= tips_data.loc[tips_data['day'] == "Thur"]
fri= tips_data.loc[tips_data['day'] == "Fri"]
sat= tips_data.loc[tips_data['day'] == "Sat"]
sun= tips_data.loc[tips_data['day'] == "Sun"]
plt.figure(figsize=(8, 8)) 
plt.suptitle("Tips of Different Days", fontsize=15, color='red')
plt.subplot(221)
plt.plot([0], [thur['tip'].mean()],"*",color="r",)
plt.plot(thur.index,thur['tip'])
plt.title("Thursday")
plt.subplot(222)
plt.plot([0], [fri['tip'].mean()],"*",color="r",)
plt.plot(fri.index,fri['tip'])
plt.title("Friday")
plt.subplot(223)
plt.plot([0], [sat['tip'].mean()],"*",color="r",)
plt.plot(sat.index,sat['tip'])
plt.title("Satday")
plt.subplot(224)
plt.plot([0], [sun['tip'].mean()],"*",color="r",)
plt.plot(sun.index,sun['tip'])
plt.title("Sunday")
# Out:
# Text(0.5, 1.0, 'Sunday')

# %%
plt.pie([fri["tip"].sum(),sat["tip"].sum(),sun["tip"].sum(),thur["tip"].sum()],labels=["Fri","Sat","Sun",'Thur'], autopct="%0.2f%%")
plt.axis('equal')
# Out:
# (-1.1107643640172367,
#  1.1005125887627256,
#  -1.113064506985197,
#  1.1018417142203594)

# %%
salary_data=pd.read_csv("ds_salaries.csv")
salary_data.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
#Do excecutive level employees usually get more salary than other employees? 
exp=salary_data['salary_in_usd'].groupby(salary_data['experience_level'])
exp.mean()
# Out:
# experience_level
# EN     61643.318182
# EX    199392.038462
# MI     87996.056338
# SE    138617.292857
# Name: salary_in_usd, dtype: float64

# %%
mi= salary_data.loc[salary_data['experience_level'] == "MI"]
mi.sample(10)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 77           77       2021               MI              PT
# 245         245       2021               MI              FT
# 415         415       2022               MI              FT
# 57           57       2020               MI              FT
# 95           95       2021               MI              FT
# 218         218       2021               MI              FT
# 567         567       2022               MI              FT
# 390         390       2022               MI              FT
# 478         478       2022               MI              FT
# 280         280       2021               MI              FT
#
#                          job_title  salary salary_currency  salary_in_usd  \
# 77   3D Computer Vision Researcher  400000             INR           5409
# 245                  Data Engineer   52500             GBP          72212
# 415                  Data Engineer   45000             GBP          58894
# 57                  Data Scientist  118000             USD         118000
# 95             Cloud Data Engineer  120000             SGD          89294
# 218      Machine Learning Engineer   75000             EUR          88654
# 567                   Data Analyst   50000             GBP          65438
# 390      Machine Learning Engineer   75000             GBP          98158
# 478                 Data Scientist  200000             USD         200000
# 280                  Data Engineer  112000             USD         112000
#
#     employee_residence  remote_ratio company_location company_size
# 77                  IN            50               IN            M
# 245                 GB            50               GB            L
# 415                 GB           100               GB            M
# 57                  US           100               US            M
# 95                  SG            50               SG            L
# 218                 BE           100               BE            M
# 567                 GB             0               GB            M
# 390                 GB             0               GB            M
# 478                 US           100               US            M
# 280                 US           100               US            L

# %%
en= salary_data.loc[salary_data['experience_level'] == "EN"]
en.sample(frac=0.1, replace = True)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 316         316       2022               EN              FT
# 72           72       2021               EN              FT
# 52           52       2020               EN              FT
# 109         109       2021               EN              FT
# 128         128       2021               EN              FT
# 253         253       2021               EN              FT
# 96           96       2021               EN              PT
# 521         521       2022               EN              FT
# 449         449       2022               EN              FT
#
#                      job_title   salary salary_currency  salary_in_usd  \
# 316              Data Engineer    35000             GBP          45807
# 72          Research Scientist    60000             GBP          82528
# 52                AI Scientist   300000             DKK          45896
# 109              Data Engineer  2250000             INR          30428
# 128  Machine Learning Engineer    20000             USD          20000
# 253             Data Scientist  2100000             INR          28399
# 96                AI Scientist    12000             USD          12000
# 521   Computer Vision Engineer    10000             USD          10000
# 449                ML Engineer    20000             EUR          21983
#
#     employee_residence  remote_ratio company_location company_size
# 316                 GB           100               GB            M
# 72                  GB            50               GB            L
# 52                  DK            50               DK            S
# 109                 IN           100               IN            L
# 128                 IN           100               IN            S
# 253                 IN           100               IN            M
# 96                  BR           100               US            S
# 521                 PT           100               LU            M
# 449                 PT           100               PT            L

# %%
ex= salary_data.loc[salary_data['experience_level'] == "EX"]
ex.sample(frac=0.1, replace = True)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 343         343       2022               EX              FT
# 375         375       2022               EX              FT
# 344         344       2022               EX              FT
#
#                 job_title  salary salary_currency  salary_in_usd  \
# 343  Head of Data Science  167875             USD         167875
# 375    Lead Data Engineer  150000             CAD         118187
# 344    Analytics Engineer  175000             USD         175000
#
#     employee_residence  remote_ratio company_location company_size
# 343                 US           100               US            M
# 375                 CA           100               CA            S
# 344                 US           100               US            M

# %%
se= salary_data.loc[salary_data['experience_level'] == "SE"]
se.sample(frac=0.1, replace = True)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 580         580       2022               SE              FT
# 529         529       2022               SE              FT
# 372         372       2022               SE              FT
# 138         138       2021               SE              FT
# 446         446       2022               SE              FT
# 395         395       2022               SE              FT
# 469         469       2022               SE              FT
# 165         165       2021               SE              FT
# 494         494       2022               SE              FT
# 285         285       2021               SE              FT
# 544         544       2022               SE              FT
# 585         585       2022               SE              FT
# 468         468       2022               SE              FT
# 569         569       2022               SE              FT
# 346         346       2022               SE              FT
# 380         380       2022               SE              FT
# 588         588       2022               SE              FT
# 383         383       2022               SE              FT
# 574         574       2022               SE              FT
# 409         409       2022               SE              FT
# 305         305       2022               SE              FT
# 232         232       2021               SE              FT
# 4             4       2020               SE              FT
# 174         174       2021               SE              FT
# 197         197       2021               SE              FT
# 417         417       2022               SE              FT
# 379         379       2022               SE              FT
# 175         175       2021               SE              FT
#
#                         job_title   salary salary_currency  salary_in_usd  \
# 580                  Data Analyst   126500             USD         126500
# 529                  Data Analyst    90320             USD          90320
# 372     Machine Learning Engineer   164996             USD         164996
# 138      Principal Data Scientist   220000             USD         220000
# 446                 Data Engineer   209100             USD         209100
# 395        Data Analytics Manager   105400             USD         105400
# 469                Data Scientist   140000             USD         140000
# 165               Data Specialist   165000             USD         165000
# 494                Data Scientist   100000             USD         100000
# 285          Data Science Manager  7000000             INR          94665
# 544                 Data Engineer   130000             USD         130000
# 585                  Data Analyst   110925             USD         110925
# 468                 Data Engineer   100000             USD         100000
# 569                Data Scientist   140000             USD         140000
# 346                 Data Engineer   108800             USD         108800
# 380                 Data Engineer   136994             USD         136994
# 588                  Data Analyst    99000             USD          99000
# 383                  Data Analyst    93700             USD          93700
# 574                Data Scientist   210000             USD         210000
# 409                Data Scientist   180000             USD         180000
# 305                  Data Analyst    99000             USD          99000
# 232  Director of Data Engineering   200000             USD         200000
# 4       Machine Learning Engineer   150000             USD         150000
# 174            Research Scientist    51400             EUR          60757
# 197     Machine Learning Engineer  1799997             INR          24342
# 417         Data Science Engineer    60000             USD          60000
# 379                Data Architect   147800             USD         147800
# 175      Data Engineering Manager   174000             USD         174000
#
#     employee_residence  remote_ratio company_location company_size
# 580                 US           100               US            M
# 529                 US           100               US            M
# 372                 US             0               US            M
# 138                 US             0               US            L
# 446                 US           100               US            L
# 395                 US           100               US            M
# 469                 US           100               US            M
# 165                 US           100               US            L
# 494                 BR           100               US            M
# 285                 IN            50               IN            L
# 544                 US           100               US            M
# 585                 US           100               US            M
# 468                 US           100               US            M
# 569                 US           100               US            M
# 346                 US             0               US            M
# 380                 US           100               US            M
# 588                 US             0               US            M
# 383                 US           100               US            M
# 574                 US           100               US            M
# 409                 US           100               US            M
# 305                 US             0               US            M
# 232                 US           100               US            L
# 4                   US            50               US            L
# 174                 PT            50               PT            L
# 197                 IN           100               IN            L
# 417                 AR           100               MX            L
# 379                 US           100               US            M
# 175                 US           100               US            L

# %%
salary_data['salary_in_usd'].groupby(salary_data['experience_level']).count()
# Out:
# experience_level
# EN     88
# EX     26
# MI    213
# SE    280
# Name: salary, dtype: int64

# %%
x=["Entry-level", "Mid-level","Senior-level", "Executive-level"]
y=[]
y.append(len(en.index))
y.append(len(mi.index))
y.append(len(se.index))
y.append(len(ex.index))
plt.title("Comparing Number of Employees Based on Experience Level")
plt.xlabel("Experience Level")
plt.ylabel("Number of Employees")
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.subplot(111)
plt.plot([x for x in range(len(en.index))], en['salary_in_usd'],"+",color="r",label="Entry-level")
plt.plot([x for x in range(len(mi.index))], mi['salary_in_usd'],"*",color="b", label="Mid-level")
plt.plot([x for x in range(len(se.index))], se['salary_in_usd'],"o",color="g",label="Senior-level")
nplt.plot([x for x in range(len(ex.index))], ex['salary_in_usd'],"^",color="brown", label="Executive-level")
plt.legend()

# %%
plt.boxplot([en['salary_in_usd'],mi['salary_in_usd'],se['salary_in_usd'],ex['salary_in_usd']], labels=["Entry-level", "Mid-level","Senior-level", "Executive-level"])
plt.title("Boxplots of Salaries by Experience Level")
plt.xlabel("Salary")
plt.ylabel("Experience Level")
# Out:
# Text(0, 0.5, 'Experience Level')

# %%
#Do employees tends to get more salary based on their experience level?
exp_grouped_data=salary_data['salary_in_usd'].groupby(salary_data['experience_level'])
exp_grouped_data.mean()#26
#salary_data['salary_in_usd'].groupby(salary_data['experience_level']).count()
# Out:
# experience_level
# EN     61643.318182
# EX    199392.038462
# MI     87996.056338
# SE    138617.292857
# Name: salary_in_usd, dtype: float64

# %%
en= salary_data.loc[salary_data['experience_level'] == "EN"]
mi= salary_data.loc[salary_data['experience_level'] == "MI"]
ex= salary_data.loc[salary_data['experience_level'] == "EX"]
se= salary_data.loc[salary_data['experience_level'] == "SE"]
plt.figure(figsize=(8, 8)) 
plt.suptitle("Salaries of Different Employees", fontsize=15, color='red')
plt.subplot(221)
plt.plot([0], [en['salary_in_usd'].mean()],"*",color="r",)
plt.plot(en.index,en['salary_in_usd'])
plt.title("Entry Level")
plt.subplot(222)
plt.plot([0], [mi['salary_in_usd'].mean()],"*",color="r",)
plt.plot(mi.index,mi['salary_in_usd'])
plt.title("Mid-level")
plt.subplot(223)
plt.plot([0], [se['salary_in_usd'].mean()],"*",color="r",)
plt.plot(se.index,se['salary_in_usd'])
plt.title("Senior-level")
plt.subplot(224)
plt.plot([0], [ex['salary_in_usd'].mean()],"*",color="r",)
plt.plot(ex.index,ex['salary_in_usd'])
plt.title("Executive-level")
# Out:
# Text(0.5, 1.0, 'Executive-level')

# %%
#plt.pie([en["salary_in_usd"].mean(),mi["salary_in_usd"].mean(),se["salary_in_usd"].mean(),ex["salary_in_usd"].mean()],labels=["Entry-level", "Mid-level","Senior-level", "Executive-level"], autopct="%0.2f%%")
plt.pie([en["salary_in_usd"].sum(),mi["salary_in_usd"].sum(),se["salary_in_usd"].sum(),ex["salary_in_usd"].sum()],labels=["Entry-level", "Mid-level","Senior-level", "Executive-level"], autopct="%0.2f%%")
plt.axis('equal')
# Out:
# (-1.1028633939438122,
#  1.1001363520925624,
#  -1.1107919889656575,
#  1.1092725187004435)

# %%
#Do contractual employee work more remotely than the part timer, full timer or freelancers?
et=salary_data['remote_ratio'].groupby(salary_data['employment_type'])
et.mean()
# Out:
# employment_type
# CT    100.000000
# FL     62.500000
# FT     70.748299
# PT     70.000000
# Name: remote_ratio, dtype: float64

# %%
cl= salary_data.loc[salary_data['employment_type'] == "CT"]
cl.sample(5)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 225         225       2021               EX              CT
# 283         283       2021               SE              CT
# 78           78       2021               MI              CT
# 489         489       2022               EN              CT
# 28           28       2020               EN              CT
#
#                               job_title  salary salary_currency  \
# 225            Principal Data Scientist  416000             USD
# 283                Staff Data Scientist  105000             USD
# 78                          ML Engineer  270000             USD
# 489  Applied Machine Learning Scientist   29000             EUR
# 28                Business Data Analyst  100000             USD
#
#      salary_in_usd employee_residence  remote_ratio company_location  \
# 225         416000                 US           100               US
# 283         105000                 US           100               US
# 78          270000                 US           100               US
# 489          31875                 TN           100               CZ
# 28          100000                 US           100               US
#
#     company_size
# 225            S
# 283            M
# 78             L
# 489            M
# 28             L

# %%
ft= salary_data.loc[salary_data['employment_type'] == "FT"]
ft.sample(frac=0.1, replace = True)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 60           60       2020               MI              FT
# 1             1       2020               SE              FT
# 342         342       2022               EX              FT
# 105         105       2021               MI              FT
# 39           39       2020               EN              FT
# 199         199       2021               EN              FT
# 351         351       2022               SE              FT
# 180         180       2021               MI              FT
# 362         362       2022               SE              FT
# 547         547       2022               SE              FT
# 539         539       2022               MI              FT
# 150         150       2021               SE              FT
# 88           88       2021               SE              FT
# 372         372       2022               SE              FT
# 38           38       2020               EN              FT
# 520         520       2022               MI              FT
# 267         267       2021               MI              FT
# 36           36       2020               MI              FT
# 221         221       2021               MI              FT
# 411         411       2022               MI              FT
# 339         339       2022               SE              FT
# 453         453       2022               MI              FT
# 88           88       2021               SE              FT
# 257         257       2021               SE              FT
# 406         406       2022               MI              FT
# 108         108       2021               SE              FT
# 42           42       2020               MI              FT
# 451         451       2022               MI              FT
# 235         235       2021               MI              FT
# 573         573       2022               SE              FT
# 101         101       2021               SE              FT
# 108         108       2021               SE              FT
# 468         468       2022               SE              FT
# 530         530       2022               MI              FT
# 600         600       2022               EN              FT
# 485         485       2022               SE              FT
# 226         226       2021               SE              FT
# 521         521       2022               EN              FT
# 291         291       2022               SE              FT
# 279         279       2021               EN              FT
# 465         465       2022               EN              FT
# 594         594       2022               SE              FT
# 275         275       2021               EN              FT
# 46           46       2020               MI              FT
# 536         536       2022               SE              FT
# 221         221       2021               MI              FT
# 34           34       2020               MI              FT
# 32           32       2020               SE              FT
# 296         296       2022               SE              FT
# 87           87       2021               MI              FT
# 501         501       2022               MI              FT
# 268         268       2021               MI              FT
# 408         408       2022               MI              FT
# 584         584       2022               SE              FT
# 509         509       2022               MI              FT
# 202         202       2021               MI              FT
# 253         253       2021               EN              FT
# 19           19       2020               MI              FT
# 270         270       2021               EN              FT
#
#                                     job_title   salary salary_currency  \
# 60                              Data Engineer   110000             USD
# 1                  Machine Learning Scientist   260000             USD
# 342                      Head of Data Science   224000             USD
# 105                              Data Analyst    37456             GBP
# 39                  Machine Learning Engineer   138000             USD
# 199                   Data Science Consultant    90000             USD
# 351                      Data Science Manager   137141             USD
# 180                         Big Data Engineer  1672000             INR
# 362                              Data Analyst   130000             USD
# 547                             Data Engineer   130000             USD
# 539                            Data Scientist   102100             USD
# 150                  Director of Data Science   168000             USD
# 88                          Lead Data Analyst   170000             USD
# 372                 Machine Learning Engineer   164996             USD
# 38                               Data Analyst    10000             USD
# 520                            Data Scientist    88000             CAD
# 267                             Data Engineer   111775             USD
# 36                    Data Science Consultant   103000             USD
# 221                            Data Scientist    85000             GBP
# 411                            Data Scientist    35000             GBP
# 339                              Data Analyst   109280             USD
# 453                 Machine Learning Engineer   120000             USD
# 88                          Lead Data Analyst   170000             USD
# 257                  Principal Data Scientist   147000             EUR
# 406                              Data Analyst    58000             USD
# 108                             Data Engineer   150000             USD
# 42   Machine Learning Infrastructure Engineer    44000             EUR
# 451                Machine Learning Developer   100000             CAD
# 235                      Head of Data Science   110000             USD
# 573                              Data Analyst    69000             USD
# 101                             Data Engineer   150000             USD
# 108                             Data Engineer   150000             USD
# 468                             Data Engineer   100000             USD
# 530                              Data Analyst    85000             USD
# 600                              Data Analyst    67000             USD
# 485                 Machine Learning Engineer   120000             USD
# 226                            Data Scientist   110000             CAD
# 521                  Computer Vision Engineer    10000             USD
# 291                              Data Analyst   120600             USD
# 279                     Business Data Analyst    50000             EUR
# 465                             Data Engineer   120000             USD
# 594                    Data Analytics Manager   150260             USD
# 275                            Data Scientist   100000             USD
# 46                             Data Scientist    60000             GBP
# 536                              Data Analyst   112900             USD
# 221                            Data Scientist    85000             GBP
# 34                               Data Analyst    41000             EUR
# 32                             Data Scientist    60000             EUR
# 296                              Data Analyst   102100             USD
# 87                    Data Analytics Engineer   110000             USD
# 501                              Head of Data    30000             EUR
# 268                             Data Engineer   250000             TRY
# 408                              Data Analyst    40000             GBP
# 584                              Data Analyst   105000             USD
# 509                    Applied Data Scientist   157000             USD
# 202                            Data Scientist    32000             EUR
# 253                            Data Scientist  2100000             INR
# 19                         Lead Data Engineer    56000             USD
# 270                             Data Engineer    72500             USD
#
#      salary_in_usd employee_residence  remote_ratio company_location  \
# 60          110000                 US           100               US
# 1           260000                 JP             0               JP
# 342         224000                 US           100               US
# 105          51519                 GB            50               GB
# 39          138000                 US           100               US
# 199          90000                 US           100               US
# 351         137141                 US           100               US
# 180          22611                 IN             0               IN
# 362         130000                 CA           100               CA
# 547         130000                 US           100               US
# 539         102100                 US             0               US
# 150         168000                 JP             0               JP
# 88          170000                 US           100               US
# 372         164996                 US             0               US
# 38           10000                 NG           100               NG
# 520          69336                 CA           100               CA
# 267         111775                 US             0               US
# 36          103000                 US           100               US
# 221         116914                 GB            50               GB
# 411          45807                 GB             0               GB
# 339         109280                 US           100               US
# 453         120000                 US           100               US
# 88          170000                 US           100               US
# 257         173762                 DE           100               DE
# 406          58000                 US             0               US
# 108         150000                 US           100               US
# 42           50180                 PT             0               PT
# 451          78791                 CA           100               CA
# 235         110000                 US             0               US
# 573          69000                 US           100               US
# 101         150000                 US           100               US
# 108         150000                 US           100               US
# 468         100000                 US           100               US
# 530          85000                 CA             0               CA
# 600          67000                 CA             0               CA
# 485         120000                 US           100               US
# 226          87738                 CA           100               CA
# 521          10000                 PT           100               LU
# 291         120600                 US           100               US
# 279          59102                 LU           100               LU
# 465         120000                 US           100               US
# 594         150260                 US           100               US
# 275         100000                 US           100               US
# 46           76958                 GB           100               GB
# 536         112900                 US           100               US
# 221         116914                 GB            50               GB
# 34           46759                 FR            50               FR
# 32           68428                 GR           100               US
# 296         102100                 US           100               US
# 87          110000                 US           100               US
# 501          32974                 EE           100               EE
# 268          28016                 TR           100               TR
# 408          52351                 GB           100               GB
# 584         105000                 US           100               US
# 509         157000                 US           100               US
# 202          37825                 ES           100               ES
# 253          28399                 IN           100               IN
# 19           56000                 PT           100               US
# 270          72500                 US           100               US
#
#     company_size
# 60             L
# 1              S
# 342            M
# 105            L
# 39             S
# 199            S
# 351            M
# 180            L
# 362            M
# 547            M
# 539            M
# 150            S
# 88             L
# 372            M
# 38             S
# 520            M
# 267            M
# 36             L
# 221            L
# 411            M
# 339            M
# 453            S
# 88             L
# 257            M
# 406            S
# 108            M
# 42             M
# 451            M
# 235            S
# 573            M
# 101            L
# 108            M
# 468            M
# 530            M
# 600            M
# 485            M
# 226            S
# 521            M
# 291            M
# 279            L
# 465            M
# 594            M
# 275            M
# 46             S
# 536            M
# 221            L
# 34             L
# 32             L
# 296            M
# 87             L
# 501            S
# 268            M
# 408            M
# 584            M
# 509            L
# 202            L
# 253            M
# 19             M
# 270            L

# %%
fl =salary_data.loc[salary_data['employment_type'] == "FL"]
#fl.count()
fl.sample(frac=0.1, replace = True)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, work_year, experience_level, employment_type, job_title, salary, salary_currency, salary_in_usd, employee_residence, remote_ratio, company_location, company_size]
# Index: []

# %%
pt= salary_data.loc[salary_data['employment_type'] == "PT"]
pt.sample(frac=0.1, replace = True)
# Out:
#      Unnamed: 0  work_year experience_level employment_type      job_title  \
# 462         462       2022               MI              PT  Data Engineer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 462   50000             EUR          54957                 DE            50
#
#     company_location company_size
# 462               DE            L

# %%
salary_data['remote_ratio'].groupby(salary_data['employment_type']).count()
# Out:
# employment_type
# CT      5
# FL      4
# FT    588
# PT     10
# Name: remote_ratio, dtype: int64

# %%
x=["Part-time", "Full-time","Contract", "Freelance"]
y=[]
y.append(len(pt.index))
y.append(len(ft.index))
y.append(len(cl.index))
y.append(len(fl.index))
plt.title("Comparing Number of Employees Based on Employment Type")
plt.xlabel("Employment Type")
plt.ylabel("Number of Employees")
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.subplot(111)
plt.plot([x for x in range(len(pt.index))], pt['remote_ratio'],"+",color="r",label="Part-Time")
plt.plot([x for x in range(len(ft.index))], ft['remote_ratio'],"*",color="b", label="Full-Time")
plt.plot([x for x in range(len(cl.index))], cl['remote_ratio'],"o",color="g",label="Contractual")
plt.plot([x for x in range(len(fl.index))], fl['remote_ratio'],"^",color="brown", label="Freelancer")
plt.legend()

# %%
plt.boxplot([pt['remote_ratio'],fl['remote_ratio'],cl['remote_ratio'],fl['remote_ratio']], labels=["Part-time", "Full-time","Contract", "Freelance"])
plt.title("Boxplots of Remote Ratio by Employee Type")
plt.xlabel("Remote Ratio")
plt.ylabel("Employee Type")
# Out:
# Text(0, 0.5, 'Employee Type')

# %%
# Is the salary of the employeess increasing year by year?
year_grouped_data=salary_data['salary_in_usd'].groupby(salary_data['work_year'])
year_grouped_data.mean()
#salary_data['salary_in_usd'].groupby(salary_data['work_year']).count()
# Out:
# work_year
# 2020     95813.000000
# 2021     99853.792627
# 2022    124522.006289
# Name: salary_in_usd, dtype: float64

# %%
y1= salary_data.loc[salary_data['work_year'] == 2020]
y1.sample(frac=0.1, replace = True)
# Out:
#     Unnamed: 0  work_year experience_level employment_type  \
# 53          53       2020               EN              FT
# 32          32       2020               SE              FT
# 66          66       2020               EN              FT
# 2            2       2020               SE              FT
# 1            1       2020               SE              FT
# 44          44       2020               MI              FT
# 33          33       2020               MI              FT
# 51          51       2020               EN              FT
# 21          21       2020               MI              FT
# 39          39       2020               EN              FT
#
#                      job_title  salary salary_currency  salary_in_usd  \
# 53               Data Engineer   48000             EUR          54742
# 32              Data Scientist   60000             EUR          68428
# 66              Data Scientist   43200             EUR          49268
# 2            Big Data Engineer   85000             GBP         109024
# 1   Machine Learning Scientist  260000             USD         260000
# 44               Data Engineer   88000             GBP         112872
# 33          Research Scientist  450000             USD         450000
# 51                Data Analyst   91000             USD          91000
# 21        Product Data Analyst  450000             INR           6072
# 39   Machine Learning Engineer  138000             USD         138000
#
#    employee_residence  remote_ratio company_location company_size
# 53                 PK           100               DE            L
# 32                 GR           100               US            L
# 66                 DE             0               DE            S
# 2                  GB            50               GB            M
# 1                  JP             0               JP            S
# 44                 GB            50               GB            L
# 33                 US             0               US            M
# 51                 US           100               US            L
# 21                 IN           100               IN            L
# 39                 US           100               US            S

# %%
y2= salary_data.loc[salary_data['work_year'] == 2021]
y2.sample(frac=0.1, replace = True)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 132         132       2021               MI              FT
# 248         248       2021               SE              FT
# 216         216       2021               EN              PT
# 141         141       2021               SE              FT
# 207         207       2021               SE              FT
# 236         236       2021               MI              FT
# 288         288       2021               MI              FT
# 179         179       2021               MI              FT
# 104         104       2021               MI              FT
# 145         145       2021               SE              FT
# 275         275       2021               EN              FT
# 145         145       2021               SE              FT
# 283         283       2021               SE              CT
# 152         152       2021               MI              FT
# 279         279       2021               EN              FT
# 196         196       2021               EN              FT
# 213         213       2021               EN              FT
# 215         215       2021               SE              FT
# 84           84       2021               EX              FT
# 203         203       2021               SE              FT
# 145         145       2021               SE              FT
# 185         185       2021               MI              FT
#
#                               job_title  salary salary_currency  \
# 132  Applied Machine Learning Scientist   38400             USD
# 248                       Data Engineer   70000             GBP
# 216            Computer Vision Engineer  180000             DKK
# 141                Data Science Manager  240000             USD
# 207                       Data Engineer  165000             USD
# 236                  Research Scientist   80000             CAD
# 288           Machine Learning Engineer   43200             EUR
# 179                      Data Scientist  420000             INR
# 104                      Data Scientist   73000             USD
# 145           Machine Learning Engineer   70000             EUR
# 275                      Data Scientist  100000             USD
# 145           Machine Learning Engineer   70000             EUR
# 283                Staff Data Scientist  105000             USD
# 152                      Data Scientist   95000             CAD
# 279               Business Data Analyst   50000             EUR
# 196                     BI Data Analyst    9272             USD
# 213                   Big Data Engineer  435000             INR
# 215             Principal Data Engineer  185000             USD
# 84             Director of Data Science  130000             EUR
# 203                  Research Scientist   50000             USD
# 145           Machine Learning Engineer   70000             EUR
# 185                       Data Engineer    4000             USD
#
#      salary_in_usd employee_residence  remote_ratio company_location  \
# 132          38400                 VN           100               US
# 248          96282                 GB            50               GB
# 216          28609                 DK            50               DK
# 141         240000                 US             0               US
# 207         165000                 US             0               US
# 236          63810                 CA           100               CA
# 288          51064                 IT            50               IT
# 179           5679                 IN           100               US
# 104          73000                 US             0               US
# 145          82744                 BE            50               BE
# 275         100000                 US           100               US
# 145          82744                 BE            50               BE
# 283         105000                 US           100               US
# 152          75774                 CA           100               CA
# 279          59102                 LU           100               LU
# 196           9272                 KE           100               KE
# 213           5882                 IN             0               CH
# 215         185000                 US           100               US
# 84          153667                 IT           100               PL
# 203          50000                 FR           100               US
# 145          82744                 BE            50               BE
# 185           4000                 IR           100               IR
#
#     company_size
# 132            M
# 248            L
# 216            S
# 141            L
# 207            M
# 236            M
# 288            L
# 179            S
# 104            L
# 145            M
# 275            M
# 145            M
# 283            M
# 152            L
# 279            L
# 196            S
# 213            L
# 215            L
# 84             L
# 203            S
# 145            M
# 185            M

# %%
y3= salary_data.loc[salary_data['work_year'] == 2022]
y3.sample(10)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 385         385       2022               SE              FT
# 579         579       2022               SE              FT
# 464         464       2022               SE              FT
# 375         375       2022               EX              FT
# 543         543       2022               MI              FT
# 606         606       2022               MI              FT
# 596         596       2022               SE              FT
# 563         563       2022               SE              FT
# 399         399       2022               SE              FT
# 473         473       2022               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 385             Data Engineer  132320             USD         132320
# 579             Data Engineer   25000             USD          25000
# 464  Principal Data Scientist  148000             EUR         162674
# 375        Lead Data Engineer  150000             CAD         118187
# 543             Data Engineer   99100             USD          99100
# 606              AI Scientist  200000             USD         200000
# 596            Data Scientist  210000             USD         210000
# 563             Data Engineer  140250             USD         140250
# 399            Data Scientist  158200             USD         158200
# 473            Data Scientist  140000             USD         140000
#
#     employee_residence  remote_ratio company_location company_size
# 385                 US           100               US            M
# 579                 US           100               US            M
# 464                 DE           100               DE            M
# 375                 CA           100               CA            S
# 543                 US             0               US            M
# 606                 IN           100               US            L
# 596                 US           100               US            M
# 563                 US           100               US            M
# 399                 US           100               US            L
# 473                 US           100               US            M

# %%
year_grouped_data=salary_data['salary_in_usd'].groupby(salary_data['work_year'])
year_grouped_data.count()
# Out:
# work_year
# 2020     72
# 2021    217
# 2022    318
# Name: salary_in_usd, dtype: int64

# %%
x=["2020", "2021","2022"]
y=[]
y.append(len(y1.index))
y.append(len(y2.index))
y.append(len(y3.index))
plt.title("Comparing Number of Employees Based on Year")
plt.xlabel("Year")
plt.ylabel("Number of Employees")
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.subplot(111)
plt.plot([x for x in range(len(y1.index))], y1['salary_in_usd'],"+",color="r",label="2020")
plt.plot([x for x in range(len(y2.index))], y2['salary_in_usd'],"*",color="b", label="2021")
plt.plot([x for x in range(len(y3.index))], y3['salary_in_usd'],"^",color="g",label="2022")
plt.legend()

# %%
plt.boxplot([y1['salary_in_usd'],y2['salary_in_usd'],y3['salary_in_usd']], labels=["2020", "2021","2022"])
plt.title("Boxplots of Salary by Year")
plt.xlabel("Salary")
plt.ylabel("Year")
# Out:
# Text(0, 0.5, 'Year')
